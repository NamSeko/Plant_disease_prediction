# %%
import torchvision
import torch
from torchvision import transforms
from PIL import Image

# %%
classes = [
    'Bình thường',
    'Nấm đốm',
    'Phấn trắng',
]

# %%
model = torch.load('./best_model.pth')

# %%
mean = [0.4363, 0.4328, 0.3291]
std = [0.2129, 0.2075, 0.2038]

image_transforms = transforms.Compose([
    transforms.Resize((224,224)),
    transforms.ToTensor(),
    transforms.Normalize(torch.Tensor(mean), torch.Tensor(std))
])

# %%
import matplotlib.pyplot as plt
import numpy as np
def classify(model, image_transforms, image_path, classer):
    model = model.eval()
    image = Image.open(image_path)
    image = image_transforms(image).float()
    image = image.unsqueeze(0)
    
    output = model(image)
    _, predicted = torch.max(output.data, 1)
    
    predicted_label = classer[predicted.item()]

    # Hiển thị ảnh và nhãn
    plt.imshow(image.squeeze().permute(1, 2, 0))
    plt.title(predicted_label)
    plt.show()

# %% [markdown]
# ## Check xem lá bị bệnh nấm đốm, phấn trắng hay bình thường

# %%
import os
pt = os.listdir("../Picture_data/Test_data/PT")
nd = os.listdir("../Picture_data/Test_data/ND")
bt = os.listdir("../Picture_data/Test_data/BT")

# %% [markdown]
# ### Check bệnh phấn trắng

# %%
fig, axs = plt.subplots(5, 4, figsize=(10, 8))  # Adjust the figsize for desired image size

index = 0
for row in range(5):
    for col in range(4):
        if index < len(pt):
            image_path = "../Picture_data/Test_data/PT/" + str(pt[index])
            model = model.eval()
            image = Image.open(image_path)
            image = image_transforms(image).float()
            image = image.unsqueeze(0)

            output = model(image)
            _, predicted = torch.max(output.data, 1)

            predicted_label = classes[predicted.item()]

            axs[row, col].imshow(image.squeeze().permute(1, 2, 0))
            axs[row, col].set_title(predicted_label)
            axs[row, col].axis('off')
        index += 1

plt.tight_layout()
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...

# %% [markdown]
# ### Check bệnh nấm đốm

# %%
fig, axs = plt.subplots(5, 4, figsize=(10, 8))  # Adjust the figsize for desired image size

index = 0
for row in range(5):
    for col in range(4):
        if index < len(nd):
            image_path = "../Picture_data/Test_data/ND/" + str(nd[index])
            model = model.eval()
            image = Image.open(image_path)
            image = image_transforms(image).float()
            image = image.unsqueeze(0)

            output = model(image)
            _, predicted = torch.max(output.data, 1)

            predicted_label = classes[predicted.item()]

            axs[row, col].imshow(image.squeeze().permute(1, 2, 0))
            axs[row, col].set_title(predicted_label)
            axs[row, col].axis('off')
        index += 1

plt.tight_layout()
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...

# %% [markdown]
# ### Check lá bình thường

# %%
fig, axs = plt.subplots(5, 4, figsize=(10, 8))  # Adjust the figsize for desired image size

index = 0
for row in range(5):
    for col in range(4):
        if index < len(bt):
            image_path = "../Picture_data/Test_data/BT/" + str(bt[index])
            model = model.eval()
            image = Image.open(image_path)
            image = image_transforms(image).float()
            image = image.unsqueeze(0)

            output = model(image)
            _, predicted = torch.max(output.data, 1)

            predicted_label = classes[predicted.item()]

            axs[row, col].imshow(image.squeeze().permute(1, 2, 0))
            axs[row, col].set_title(predicted_label)
            axs[row, col].axis('off')
        index += 1

plt.tight_layout()
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...
